# %% [markdown]
# ## *Pandas* : Pandas is a Python Library . It is used for data analysis and data manipulation.
# #### We can use data from csv, excel or sql tables

# %%
import pandas as pd

# %%
# Create Series using Pandas
data=[12,24,36,48,60]
data_series=pd.Series(data)
data_series
# Out:
# 0    12
# 1    24
# 2    36
# 3    48
# 4    60
# dtype: int64

# %%
data_series2=pd.Series(data,index=['Student-1','Student-2','Student-3','Student-4','Student-5'])
data_series2
# Out:
# Student-1    12
# Student-2    24
# Student-3    36
# Student-4    48
# Student-5    60
# dtype: int64

# %%
#DataFrame (Table)
import numpy as np
df=pd.DataFrame(np.random.randn(5,5))
df
# Out:
#           0         1         2         3         4
# 0 -0.475356 -1.301170  0.358210  1.816540 -0.500912
# 1  0.725128  0.871376  0.110311  1.462554 -0.920012
# 2 -2.329505  0.689246 -0.443995 -0.250901 -1.715620
# 3 -0.836171  0.273690 -1.190804  0.413804  0.527633
# 4 -1.973320 -0.313988 -1.605634  0.927604  0.566489

# %%
data_set={
    'Name':['A','B','C','D','E'],
    'Age':[20,21,22,23,24],
    'City':['Delhi','Mumbai','Kolkata','Chennai','Bangalore']
}
df=pd.DataFrame(data_set)
df
# Out:
#   Name  Age       City
# 0    A   20      Delhi
# 1    B   21     Mumbai
# 2    C   22    Kolkata
# 3    D   23    Chennai
# 4    E   24  Bangalore

# %%
#Reading Data from Files
# Reading data from csv

# %%
df_netflix=pd.read_csv('/content/netflix_data.csv')
df_netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df_netflix.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
df_netflix.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast         country  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...          Sweden
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...           India
# 7784                                            Nasty C             NaN
# 7785                         Adriano Zumbo, Rachel Khoo       Australia
# 7786                                                NaN  United Kingdom
#
#               date_added  release_year  duration  \
# ...

# %%
df_netflix.shape
# Out:
# (7787, 11)

# %%
df_exam=pd.read_csv('/content/exams.csv')
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_exam['math score']
# Out:
# 0      67
# 1      40
# 2      59
# 3      77
# 4      78
#        ..
# 995    73
# 996    85
# 997    32
# 998    73
# 999    65
# Name: math score, Length: 1000, dtype: int64

# %%
df_exam[['lunch','math score']]
# Out:
#             lunch  math score
# 0        standard          67
# 1    free/reduced          40
# 2    free/reduced          59
# 3        standard          77
# 4        standard          78
# ..            ...         ...
# 995      standard          73
# 996  free/reduced          85
# 997  free/reduced          32
# 998      standard          73
# 999      standard          65
#
# [1000 rows x 2 columns]

# %%
#Row Selection
df_exam.iloc[0]
# Out:
# gender                                male
# race/ethnicity                     group A
# parental level of education    high school
# lunch                             standard
# test preparation course          completed
# math score                              67
# reading score                           67
# writing score                           63
# Name: 0, dtype: object

# %%
df_exam.loc[0]
# Out:
# gender                                male
# race/ethnicity                     group A
# parental level of education    high school
# lunch                             standard
# test preparation course          completed
# math score                              67
# reading score                           67
# writing score                           63
# Name: 0, dtype: object

# %%
df_exam[df_exam['math score']>90]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 7      male        group E                some college      standard
# 10     male        group E                some college      standard
# 39     male        group E          associate's degree      standard
# 44     male        group E                 high school      standard
# 87     male        group D                some college      standard
# 93     male        group D           bachelor's degree      standard
# 96   female        group E          associate's degree      standard
# 108    male        group B          associate's degree      standard
# 128    male        group E                some college      standard
# 148  female        group E           bachelor's degree      standard
# 157  female        group E          associate's degree  free/reduced
# 185  female        group C             master's degree      standard
# 211    male        group D          associate's degree      standard
# ...

# %%
df_exam[df_exam['math score']==100]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 44     male        group E                 high school  standard
# 128    male        group E                some college  standard
# 148  female        group E           bachelor's degree  standard
# 235    male        group C          associate's degree  standard
# 281    male        group E          associate's degree  standard
# 550  female        group E                some college  standard
# 584    male        group C           bachelor's degree  standard
# 593    male        group D           bachelor's degree  standard
# 634  female        group D             master's degree  standard
# 638    male        group E                 high school  standard
# 732    male        group E          associate's degree  standard
# 825    male        group E          associate's degree  standard
# 839    male        group E                some college  standard
# ...

# %%
df_exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exam.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.396000      69.002000      67.738000
# std      15.402871      14.737272      15.600985
# min      13.000000      27.000000      23.000000
# 25%      56.000000      60.000000      58.000000
# 50%      66.500000      70.000000      68.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
df_exam.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_exam.drop('parental level of education',axis=1,inplace=True)

# %%
df_exam
# Out:
#      gender race/ethnicity         lunch test preparation course  math score  \
# 0      male        group A      standard               completed          67
# 1    female        group D  free/reduced                    none          40
# 2      male        group E  free/reduced                    none          59
# 3      male        group B      standard                    none          77
# 4      male        group E      standard               completed          78
# ..      ...            ...           ...                     ...         ...
# 995    male        group C      standard                    none          73
# 996    male        group D  free/reduced               completed          85
# 997  female        group C  free/reduced                    none          32
# 998  female        group C      standard                    none          73
# 999    male        group A      standard               completed          65
#
#      reading score  writing score
# ...

# %% [markdown]
# ### Reading from excel

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/employees.xlsx')

# %%
df
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 0    101    Ali         IT   25   50000           3      Delhi
# 1    102   Sara         HR   28   45000           5     Mumbai
# 2    103   John         IT   30   60000           7      Delhi
# 3    104   Mike      Sales   27   42000           4       Pune
# 4    105  David         HR   35   52000          10     Mumbai
# 5    106   Ravi         IT   24   40000           2      Noida
# 6    107   Neha      Sales   29   48000           6      Delhi
# 7    108   Amit         IT   32   65000           9  Bangalore
# 8    109  Priya         HR   26   43000           3    Chennai
# 9    110  Karan      Sales   31   55000           8     Mumbai

# %%
df.head(3)
# Out:
#    EmpID  Name Department  Age  Salary  Experience    City
# 0    101   Ali         IT   25   50000           3   Delhi
# 1    102  Sara         HR   28   45000           5  Mumbai
# 2    103  John         IT   30   60000           7   Delhi

# %%
df.head(3)
# Out:
#    EmpID  Name Department  Age  Salary  Experience    City
# 0    101   Ali         IT   25   50000           3   Delhi
# 1    102  Sara         HR   28   45000           5  Mumbai
# 2    103  John         IT   30   60000           7   Delhi

# %%
#Random 5 Rows from dataframe
df.sample(5)
# Out:
#    EmpID  Name Department  Age  Salary  Experience       City
# 3    104  Mike      Sales   27   42000           4       Pune
# 0    101   Ali         IT   25   50000           3      Delhi
# 5    106  Ravi         IT   24   40000           2      Noida
# 7    108  Amit         IT   32   65000           9  Bangalore
# 2    103  John         IT   30   60000           7      Delhi

# %%
#datatypes, columns ,missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       10 non-null     int64
#  1   Name        10 non-null     object
#  2   Department  10 non-null     object
#  3   Age         10 non-null     int64
#  4   Salary      10 non-null     int64
#  5   Experience  10 non-null     int64
#  6   City        10 non-null     object
# dtypes: int64(4), object(3)
# memory usage: 692.0+ bytes

# %%
#rows and columns
df.shape
# Out:
# (10, 7)

# %%
df.columns
# Out:
# Index(['EmpID', 'Name', 'Department', 'Age', 'Salary', 'Experience', 'City'], dtype='object')

# %%
df.dtypes
# Out:
# EmpID          int64
# Name          object
# Department    object
# Age            int64
# Salary         int64
# Experience     int64
# City          object
# dtype: object

# %%
df.describe()
# Out:
#            EmpID       Age        Salary  Experience
# count   10.00000  10.00000     10.000000   10.000000
# mean   105.50000  28.70000  50000.000000    5.700000
# std      3.02765   3.40098   8137.703744    2.750757
# min    101.00000  24.00000  40000.000000    2.000000
# 25%    103.25000  26.25000  43500.000000    3.250000
# 50%    105.50000  28.50000  49000.000000    5.500000
# 75%    107.75000  30.75000  54250.000000    7.750000
# max    110.00000  35.00000  65000.000000   10.000000

# %%
df['Name']
# Out:
# 0      Ali
# 1     Sara
# 2     John
# 3     Mike
# 4    David
# 5     Ravi
# 6     Neha
# 7     Amit
# 8    Priya
# 9    Karan
# Name: Name, dtype: object

# %%
df[['Name','Salary']]
# Out:
#     Name  Salary
# 0    Ali   50000
# 1   Sara   45000
# 2   John   60000
# 3   Mike   42000
# 4  David   52000
# 5   Ravi   40000
# 6   Neha   48000
# 7   Amit   65000
# 8  Priya   43000
# 9  Karan   55000

# %%
df[['Name','Age','Salary']]
# Out:
#     Name  Age  Salary
# 0    Ali   25   50000
# 1   Sara   28   45000
# 2   John   30   60000
# 3   Mike   27   42000
# 4  David   35   52000
# 5   Ravi   24   40000
# 6   Neha   29   48000
# 7   Amit   32   65000
# 8  Priya   26   43000
# 9  Karan   31   55000

# %%
df
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 0    101    Ali         IT   25   50000           3      Delhi
# 1    102   Sara         HR   28   45000           5     Mumbai
# 2    103   John         IT   30   60000           7      Delhi
# 3    104   Mike      Sales   27   42000           4       Pune
# 4    105  David         HR   35   52000          10     Mumbai
# 5    106   Ravi         IT   24   40000           2      Noida
# 6    107   Neha      Sales   29   48000           6      Delhi
# 7    108   Amit         IT   32   65000           9  Bangalore
# 8    109  Priya         HR   26   43000           3    Chennai
# 9    110  Karan      Sales   31   55000           8     Mumbai

# %%
df[df['Salary']>50000]  #Filtering Salary greater than 50k
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 2    103   John         IT   30   60000           7      Delhi
# 4    105  David         HR   35   52000          10     Mumbai
# 7    108   Amit         IT   32   65000           9  Bangalore
# 9    110  Karan      Sales   31   55000           8     Mumbai

# %%
df[df['City']=='Delhi']  # Employee From Delhi
# Out:
#    EmpID  Name Department  Age  Salary  Experience   City
# 0    101   Ali         IT   25   50000           3  Delhi
# 2    103  John         IT   30   60000           7  Delhi
# 6    107  Neha      Sales   29   48000           6  Delhi

# %%
df[df['Department']=='IT']
# Out:
#    EmpID  Name Department  Age  Salary  Experience       City
# 0    101   Ali         IT   25   50000           3      Delhi
# 2    103  John         IT   30   60000           7      Delhi
# 5    106  Ravi         IT   24   40000           2      Noida
# 7    108  Amit         IT   32   65000           9  Bangalore

# %%
df[(df['Department']=='IT') & (df['City']=='Delhi')]
# Out:
#    EmpID  Name Department  Age  Salary  Experience   City
# 0    101   Ali         IT   25   50000           3  Delhi
# 2    103  John         IT   30   60000           7  Delhi

# %%
#Query way
df.query('Salary>50000')
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 2    103   John         IT   30   60000           7      Delhi
# 4    105  David         HR   35   52000          10     Mumbai
# 7    108   Amit         IT   32   65000           9  Bangalore
# 9    110  Karan      Sales   31   55000           8     Mumbai

# %%
#Query way
df.query('Department=="IT"')
# Out:
#    EmpID  Name Department  Age  Salary  Experience       City
# 0    101   Ali         IT   25   50000           3      Delhi
# 2    103  John         IT   30   60000           7      Delhi
# 5    106  Ravi         IT   24   40000           2      Noida
# 7    108  Amit         IT   32   65000           9  Bangalore

# %%
#Sort df based on Salary
df.sort_values(by='Salary')
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 5    106   Ravi         IT   24   40000           2      Noida
# 3    104   Mike      Sales   27   42000           4       Pune
# 8    109  Priya         HR   26   43000           3    Chennai
# 1    102   Sara         HR   28   45000           5     Mumbai
# 6    107   Neha      Sales   29   48000           6      Delhi
# 0    101    Ali         IT   25   50000           3      Delhi
# 4    105  David         HR   35   52000          10     Mumbai
# 9    110  Karan      Sales   31   55000           8     Mumbai
# 2    103   John         IT   30   60000           7      Delhi
# 7    108   Amit         IT   32   65000           9  Bangalore

# %%
#Sort df based on Salary descending
df.sort_values(by='Salary',ascending=False)
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 7    108   Amit         IT   32   65000           9  Bangalore
# 2    103   John         IT   30   60000           7      Delhi
# 9    110  Karan      Sales   31   55000           8     Mumbai
# 4    105  David         HR   35   52000          10     Mumbai
# 0    101    Ali         IT   25   50000           3      Delhi
# 6    107   Neha      Sales   29   48000           6      Delhi
# 1    102   Sara         HR   28   45000           5     Mumbai
# 8    109  Priya         HR   26   43000           3    Chennai
# 3    104   Mike      Sales   27   42000           4       Pune
# 5    106   Ravi         IT   24   40000           2      Noida

# %%
# group by department salary sum
df.groupby('Department')['Salary'].sum()
# Out:
# Department
# HR       140000
# IT       215000
# Sales    145000
# Name: Salary, dtype: int64

# %%
df.drop('Age',axis=1,inplace=True)  #Drop a column from dataframe

# %%
df.head(3)
# Out:
#    EmpID  Name Department  Salary  Experience    City
# 0    101   Ali         IT   50000           3   Delhi
# 1    102  Sara         HR   45000           5  Mumbai
# 2    103  John         IT   60000           7   Delhi

# %%
df['Bonus']=df['Salary']*0.15 # Add a new column in df

# %%
df.head(3)
# Out:
#    EmpID  Name Department  Salary  Experience    City   Bonus
# 0    101   Ali         IT   50000           3   Delhi  7500.0
# 1    102  Sara         HR   45000           5  Mumbai  6750.0
# 2    103  John         IT   60000           7   Delhi  9000.0

# %%
df['Tax']=df['Salary']*0.12

# %%
df.sample(3)
# Out:
#    EmpID  Name Department  Salary  Experience   City   Bonus     Tax
# 3    104  Mike      Sales   42000           4   Pune  6300.0  5040.0
# 2    103  John         IT   60000           7  Delhi  9000.0  7200.0
# 0    101   Ali         IT   50000           3  Delhi  7500.0  6000.0

# %%
df.nlargest(5,'Salary') #Top five salary
# Out:
#    EmpID   Name Department  Salary  Experience       City   Bonus     Tax
# 7    108   Amit         IT   65000           9  Bangalore  9750.0  7800.0
# 2    103   John         IT   60000           7      Delhi  9000.0  7200.0
# 9    110  Karan      Sales   55000           8     Mumbai  8250.0  6600.0
# 4    105  David         HR   52000          10     Mumbai  7800.0  6240.0
# 0    101    Ali         IT   50000           3      Delhi  7500.0  6000.0

# %% [markdown]
# ***Exercise***
# * Download employee_performance.xlsx from https://github.com/salman1256/aiml_evening.git
# * Read out excel file in dataframe
# * find 2 random, first , and last records
# * Sort Employees by PerformanceScore
# * Find out top 3 Performers
# * Add one more column Bonus based on Salary (Bonus=10% of Salary)

# %%
#Read out excel file in dataframe
df_performance=pd.read_excel('/content/employee_performance.xlsx')
df_performance
# Out:
#    EmpID   Name Department  Projects  HoursPerWeek  PerformanceScore  Salary  \
# 0    201    Ali         IT         5            40                85   50000
# 1    202   Sara         HR         3            38                78   45000
# 2    203   John         IT         6            45                92   65000
# 3    204   Neha      Sales         4            42                81   48000
# 4    205   Ravi         IT         2            35                70   40000
# 5    206  Priya         HR         3            37                75   43000
# 6    207  Karan      Sales         5            44                88   55000
# 7    208   Amit         IT         7            50                95   70000
# 8    209  David         HR         4            41                82   52000
# 9    210  Meena      Sales         3            39                76   46000
#
#         City
# 0      Delhi
# 1     Mumbai
# 2      Delhi
# 3       Pune
# 4      Noida
# 5    Chennai
# 6     Mumbai
# ...

# %%
#find 2 random, first , and last records
df_performance.sample(2)
# Out:
#    EmpID  Name Department  Projects  HoursPerWeek  PerformanceScore  Salary  \
# 2    203  John         IT         6            45                92   65000
# 4    205  Ravi         IT         2            35                70   40000
#
#     City
# 2  Delhi
# 4  Noida

# %%
df_performance.head(2)
# Out:
#    EmpID  Name Department  Projects  HoursPerWeek  PerformanceScore  Salary  \
# 0    201   Ali         IT         5            40                85   50000
# 1    202  Sara         HR         3            38                78   45000
#
#      City
# 0   Delhi
# 1  Mumbai

# %%
df_performance.tail(2)
# Out:
#    EmpID   Name Department  Projects  HoursPerWeek  PerformanceScore  Salary  \
# 8    209  David         HR         4            41                82   52000
# 9    210  Meena      Sales         3            39                76   46000
#
#      City
# 8  Mumbai
# 9   Delhi

# %%
#Sort Employees by PerformanceScore
df_performance.sort_values(by='PerformanceScore')
# Out:
#    EmpID   Name Department  Projects  HoursPerWeek  PerformanceScore  Salary  \
# 4    205   Ravi         IT         2            35                70   40000
# 5    206  Priya         HR         3            37                75   43000
# 9    210  Meena      Sales         3            39                76   46000
# 1    202   Sara         HR         3            38                78   45000
# 3    204   Neha      Sales         4            42                81   48000
# 8    209  David         HR         4            41                82   52000
# 0    201    Ali         IT         5            40                85   50000
# 6    207  Karan      Sales         5            44                88   55000
# 2    203   John         IT         6            45                92   65000
# 7    208   Amit         IT         7            50                95   70000
#
#         City
# 4      Noida
# 5    Chennai
# 9      Delhi
# 1     Mumbai
# 3       Pune
# 8     Mumbai
# 0      Delhi
# ...

# %%
df_performance.sort_values(by='PerformanceScore',ascending=False)
# Out:
#    EmpID   Name Department  Projects  HoursPerWeek  PerformanceScore  Salary  \
# 7    208   Amit         IT         7            50                95   70000
# 2    203   John         IT         6            45                92   65000
# 6    207  Karan      Sales         5            44                88   55000
# 0    201    Ali         IT         5            40                85   50000
# 8    209  David         HR         4            41                82   52000
# 3    204   Neha      Sales         4            42                81   48000
# 1    202   Sara         HR         3            38                78   45000
# 9    210  Meena      Sales         3            39                76   46000
# 5    206  Priya         HR         3            37                75   43000
# 4    205   Ravi         IT         2            35                70   40000
#
#         City
# 7  Bangalore
# 2      Delhi
# 6     Mumbai
# 0      Delhi
# 8     Mumbai
# 3       Pune
# 1     Mumbai
# ...

# %%
#Find out top 3 Performers
df_performance.nlargest(3,'PerformanceScore')
# Out:
#    EmpID   Name Department  Projects  HoursPerWeek  PerformanceScore  Salary  \
# 7    208   Amit         IT         7            50                95   70000
# 2    203   John         IT         6            45                92   65000
# 6    207  Karan      Sales         5            44                88   55000
#
#         City
# 7  Bangalore
# 2      Delhi
# 6     Mumbai

# %%
#Add one more column Bonus based on Salary (Bonus=10% of Salary)
df_performance['Bonus']=df_performance['Salary']*0.10

# %%
df_performance.head()
# Out:
#    EmpID  Name Department  Projects  HoursPerWeek  PerformanceScore  Salary  \
# 0    201   Ali         IT         5            40                85   50000
# 1    202  Sara         HR         3            38                78   45000
# 2    203  John         IT         6            45                92   65000
# 3    204  Neha      Sales         4            42                81   48000
# 4    205  Ravi         IT         2            35                70   40000
#
#      City   Bonus
# 0   Delhi  5000.0
# 1  Mumbai  4500.0
# 2   Delhi  6500.0
# 3    Pune  4800.0
# 4   Noida  4000.0

# %%
#few more things
#Find Max PerformanceScore
df_performance['PerformanceScore'].max()
# Out:
# 95

# %%
#Find Min PerformanceScore
df_performance['PerformanceScore'].min()
# Out:
# 70

# %%
# count employee per department
df_performance['Department'].value_counts()
# Out:
# Department
# IT       4
# HR       3
# Sales    3
# Name: count, dtype: int64

# %%
# department wise average salary
df_performance.groupby('Department')['Salary'].mean()
# Out:
# Department
# HR       46666.666667
# IT       56250.000000
# Sales    49666.666667
# Name: Salary, dtype: float64

# %%
# department wise sum of salary
df_performance.groupby('Department')['Salary'].sum()
# Out:
# Department
# HR       140000
# IT       225000
# Sales    149000
# Name: Salary, dtype: int64
