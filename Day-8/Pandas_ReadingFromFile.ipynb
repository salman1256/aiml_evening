# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/Housing_Price_Data.csv')

# %%
df.head(5)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df['price']
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
df.tail(5)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
df.to_excel('Housing_Price.xlsx')

# %%
df_excel=pd.read_excel('/content/Housing_Price.xlsx')

# %%
df_excel
# Out:
#      Unnamed: 0     price  area  bedrooms  bathrooms  stories mainroad  \
# 0             0  13300000  7420         4          2        3      yes
# 1             1  12250000  8960         4          4        4      yes
# 2             2  12250000  9960         3          2        2      yes
# 3             3  12215000  7500         4          2        2      yes
# 4             4  11410000  7420         4          1        2      yes
# ..          ...       ...   ...       ...        ...      ...      ...
# 540         540   1820000  3000         2          1        1      yes
# 541         541   1767150  2400         3          1        1       no
# 542         542   1750000  3620         2          1        1      yes
# 543         543   1750000  2910         3          1        1       no
# 544         544   1750000  3850         3          1        2      yes
#
#     guestroom basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# **Day-08 Exercise-01**
# * Use https://www.kaggle.com/datasets/vaibhavdube99/titatnic-flood data set
# ## Do the following tasks:
#  1.  Load .csv into a pandas Data frame
#  2. Display first 20 rows
#  3. Get the shape of dataset
#  4. Show summary statistics
#  5. drop 2 columns from data frame
#  6. Write back to an .xlsx file

# %% [markdown]
# **Data Cleaning Using Pandas**
#
# ---

# %%
emp_data={
    'Name':['John','Jane','Mike','Mary','Rohit','Sam'],
    'Age':[25,None,35,40,30,35],
    'Salary':[2000,None,4000,5000,None,9000]
}

# %%
df=pd.DataFrame(emp_data)

# %%
df.head(5)
# Out:
#     Name   Age  Salary
# 0   John  25.0  2000.0
# 1   Jane   NaN     NaN
# 2   Mike  35.0  4000.0
# 3   Mary  40.0  5000.0
# 4  Rohit  30.0     NaN

# %%
print('Missing Data')
print('Number of Missing Values:\n',df.isnull().sum())
#
# Out:
# Missing Data
# Number of Missing Values:
#  Name      0
# Age       1
# Salary    2
# dtype: int64

# %%
# dropna() or fillna() or mean

# %%
#Remove missing values.
cleaned_df=df.dropna()

# %%
print('Original Data frame: shape',df.shape)
df
# Out:
# Original Data frame: shape (6, 3)
#     Name   Age  Salary
# 0   John  25.0  2000.0
# 1   Jane   NaN     NaN
# 2   Mike  35.0  4000.0
# 3   Mary  40.0  5000.0
# 4  Rohit  30.0     NaN
# 5    Sam  35.0  9000.0

# %%
print('Cleaned Data frame',cleaned_df.shape)
cleaned_df
# Out:
# Cleaned Data frame (4, 3)
#    Name   Age  Salary
# 0  John  25.0  2000.0
# 2  Mike  35.0  4000.0
# 3  Mary  40.0  5000.0
# 5   Sam  35.0  9000.0

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#    Name   Age  Salary
# 0  John  25.0  2000.0
# 2  Mike  35.0  4000.0
# 3  Mary  40.0  5000.0
# 5   Sam  35.0  9000.0

# %%
emp_data={
    'Name':['John','Jane','Mike','Mary','Rohit','Sam'],
    'Age':[25,None,35,40,30,35],
    'Salary':[2000,None,4000,5000,None,9000]
}

# %%
df=pd.DataFrame(emp_data)
df
# Out:
#     Name   Age  Salary
# 0   John  25.0  2000.0
# 1   Jane   NaN     NaN
# 2   Mike  35.0  4000.0
# 3   Mary  40.0  5000.0
# 4  Rohit  30.0     NaN
# 5    Sam  35.0  9000.0

# %%
avg_salary=df['Salary'].mean()
avg_age=df['Age'].mean()
print('Average Salary:',avg_salary)
print('Average Age:',avg_age)
# Out:
# Average Salary: 5000.0
# Average Age: 33.0

# %%
df['Salary']=df['Salary'].fillna(avg_salary)

# %%
df
# Out:
#     Name   Age  Salary
# 0   John  25.0  2000.0
# 1   Jane   NaN  5000.0
# 2   Mike  35.0  4000.0
# 3   Mary  40.0  5000.0
# 4  Rohit  30.0  5000.0
# 5    Sam  35.0  9000.0

# %%
df['Age']=df['Age'].fillna(avg_age )

# %%
df
# Out:
#     Name   Age  Salary
# 0   John  25.0  2000.0
# 1   Jane  33.0  5000.0
# 2   Mike  35.0  4000.0
# 3   Mary  40.0  5000.0
# 4  Rohit  30.0  5000.0
# 5    Sam  35.0  9000.0

# %%
emp_data={
    'Name':['John','Jane','Riya','Mike','Mary','Rohit','Sam','John','Riya'],
    'Salary':[2000,2000,3500,4000,5000,2500,9000,2000,3500]
}

# %%
df=pd.DataFrame(emp_data)

# %%
df
# Out:
#     Name  Salary
# 0   John    2000
# 1   Jane    2000
# 2   Riya    3500
# 3   Mike    4000
# 4   Mary    5000
# 5  Rohit    2500
# 6    Sam    9000
# 7   John    2000
# 8   Riya    3500

# %%
print('Shape of original Data Frame',df.shape)
print(df.to_string(index=False))
# Out:
# Shape of original Data Frame (9, 2)
#  Name  Salary
#  John    2000
#  Jane    2000
#  Riya    3500
#  Mike    4000
#  Mary    5000
# Rohit    2500
#   Sam    9000
#  John    2000
#  Riya    3500

# %%
print(df.duplicated().to_string(index=False))
# Out:
# False
# False
# False
# False
# False
# False
# False
#  True
#  True

# %%
df.drop_duplicates(inplace=True)

# %%
print('Shape of Data Frame after deleting duplicate',df.shape)
df
# Out:
# Shape of Data Frame after deleting duplicate (7, 2)
#     Name  Salary
# 0   John    2000
# 1   Jane    2000
# 2   Riya    3500
# 3   Mike    4000
# 4   Mary    5000
# 5  Rohit    2500
# 6    Sam    9000

# %%
df
# Out:
#     Name  Salary
# 0   John    2000
# 1   Jane    2000
# 2   Riya    3500
# 3   Mike    4000
# 4   Mary    5000
# 5  Rohit    2500
# 6    Sam    9000

# %%
df.rename(columns={'Name':'Employee Name'},inplace=True)

# %%
df
# Out:
#   Employee Name  Salary
# 0          John    2000
# 1          Jane    2000
# 2          Riya    3500
# 3          Mike    4000
# 4          Mary    5000
# 5         Rohit    2500
# 6           Sam    9000

# %%
df.rename(columns={'Salary':'Employee Salary'},inplace=True)

# %%
df
# Out:
#   Employee Name  Employee Salary
# 0          John             2000
# 1          Jane             2000
# 2          Riya             3500
# 3          Mike             4000
# 4          Mary             5000
# 5         Rohit             2500
# 6           Sam             9000

# %%
df.rename(columns={'Employee Name':'name','Employee Salary':'salary'},inplace=True)

# %%
df
# Out:
#     name  salary
# 0   John    2000
# 1   Jane    2000
# 2   Riya    3500
# 3   Mike    4000
# 4   Mary    5000
# 5  Rohit    2500
# 6    Sam    9000
