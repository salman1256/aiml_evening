# %% [markdown]
# Pandas  is a Python library, It is used in Python data anlysis for
# * Data Cleaning
# * Data Manipulation
# * Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
#Create 1.Series, 2.DataFrames 3. Read out from External files 4. DataCleaning : Pandas function
pd_series = pd.Series([10,12,30,14,15])
pd_series
# Out:
# 0    10
# 1    12
# 2    30
# 3    14
# 4    15
# dtype: int64

# %%
df=pd.DataFrame(
    {
        'Student Name':['Sam','Ravi','Amit','Vijay','Alina','Ravi','Zoya','Nilam','Deep'],
        'Student Marks':[90,87,67,45,91,87,92,78,89]
    }
)

# %%
df
# Out:
#   Student Name  Student Marks
# 0          Sam             90
# 1         Ravi             87
# 2         Amit             67
# 3        Vijay             45
# 4        Alina             91
# 5         Ravi             87
# 6         Zoya             92
# 7        Nilam             78
# 8         Deep             89

# %%
#shows first n rows , if you have not specify number of rows , it will show you first 5
df.head()
# Out:
#   Student Name  Student Marks
# 0          Sam             90
# 1         Ravi             87
# 2         Amit             67
# 3        Vijay             45
# 4        Alina             91

# %%
df.head(2)
# Out:
#   Student Name  Student Marks
# 0          Sam             90
# 1         Ravi             87

# %%
df.tail() #Return the last n rows.
# Out:
#   Student Name  Student Marks
# 4        Alina             91
# 5         Ravi             87
# 6         Zoya             92
# 7        Nilam             78
# 8         Deep             89

# %%
df.tail(2)
# Out:
#   Student Name  Student Marks
# 7        Nilam             78
# 8         Deep             89

# %%
df.info() #Print a concise summary of a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student Name   9 non-null      object
#  1   Student Marks  9 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 276.0+ bytes

# %%
df.describe() #Generate descriptive statistics.
# Out:
#        Student Marks
# count       9.000000
# mean       80.666667
# std        15.564382
# min        45.000000
# 25%        78.000000
# 50%        87.000000
# 75%        90.000000
# max        92.000000

# %%
df.shape #return number of rows and number of columns
# Out:
# (9, 2)

# %%
df.dtypes
# Out:
# Student Name     object
# Student Marks     int64
# dtype: object

# %%
df['Student Marks']
# Out:
# 0    90
# 1    87
# 2    67
# 3    45
# 4    91
# 5    87
# 6    92
# 7    78
# 8    89
# Name: Student Marks, dtype: int64

# %%
print(df['Student Marks'])
# Out:
# 0    90
# 1    87
# 2    67
# 3    45
# 4    91
# 5    87
# 6    92
# 7    78
# 8    89
# Name: Student Marks, dtype: int64

# %%
df[['Student Name', 'Student Marks']]
# Out:
#   Student Name  Student Marks
# 0          Sam             90
# 1         Ravi             87
# 2         Amit             67
# 3        Vijay             45
# 4        Alina             91
# 5         Ravi             87
# 6         Zoya             92
# 7        Nilam             78
# 8         Deep             89

# %%
df['Student Name']
# Out:
# 0      Sam
# 1     Ravi
# 2     Amit
# 3    Vijay
# 4    Alina
# 5     Ravi
# 6     Zoya
# 7    Nilam
# 8     Deep
# Name: Student Name, dtype: object

# %% [markdown]
# loc:label based

# %%
df.loc[0]
# Out:
# Student Name     Sam
# Student Marks     90
# Name: 0, dtype: object

# %%
df.loc[0:2]
# Out:
#   Student Name  Student Marks
# 0          Sam             90
# 1         Ravi             87
# 2         Amit             67

# %%
df.loc[:2]
# Out:
#   Student Name  Student Marks
# 0          Sam             90
# 1         Ravi             87
# 2         Amit             67

# %%
df.loc[:,'Student Marks']
# Out:
# 0    90
# 1    87
# 2    67
# 3    45
# 4    91
# 5    87
# 6    92
# 7    78
# 8    89
# Name: Student Marks, dtype: int64

# %%
df.loc[:,'Student Name']
# Out:
# 0      Sam
# 1     Ravi
# 2     Amit
# 3    Vijay
# 4    Alina
# 5     Ravi
# 6     Zoya
# 7    Nilam
# 8     Deep
# Name: Student Name, dtype: object

# %%
df.loc[:3,'Student Name']
# Out:
# 0      Sam
# 1     Ravi
# 2     Amit
# 3    Vijay
# Name: Student Name, dtype: object

# %%
# iloc (index -based)
df.iloc[0]  #first row
# Out:
# Student Name     Sam
# Student Marks     90
# Name: 0, dtype: object

# %%
df.iloc[0:2] #first 2 rows
# Out:
#   Student Name  Student Marks
# 0          Sam             90
# 1         Ravi             87

# %%
df.iloc[:,1] #for all Student Marks
# Out:
# 0    90
# 1    87
# 2    67
# 3    45
# 4    91
# 5    87
# 6    92
# 7    78
# 8    89
# Name: Student Marks, dtype: int64

# %%
df.iloc[:,0] # all student Name
# Out:
# 0      Sam
# 1     Ravi
# 2     Amit
# 3    Vijay
# 4    Alina
# 5     Ravi
# 6     Zoya
# 7    Nilam
# 8     Deep
# Name: Student Name, dtype: object

# %%
df[df['Student Marks']>90]
# Out:
#   Student Name  Student Marks
# 4        Alina             91
# 6         Zoya             92

# %%
df[df['Student Name']=='Sam']
# Out:
#   Student Name  Student Marks
# 0          Sam             90

# %% [markdown]
# **Adding columns**

# %%
df['Student Attendance']=[92,87,67,45,91,87,92,78,89]

# %%
df
# Out:
#   Student Name  Student Marks  Student Attendance
# 0          Sam             90                  92
# 1         Ravi             87                  87
# 2         Amit             67                  67
# 3        Vijay             45                  45
# 4        Alina             91                  91
# 5         Ravi             87                  87
# 6         Zoya             92                  92
# 7        Nilam             78                  78
# 8         Deep             89                  89

# %%
#Remove the Column
df=df.drop('Student Marks',axis=1)

# %%
df
# Out:
#   Student Name  Student Marks  Student Attendance
# 0          Sam             90                  92
# 1         Ravi             87                  87
# 2         Amit             67                  67
# 3        Vijay             45                  45
# 4        Alina             91                  91
# 5         Ravi             87                  87
# 6         Zoya             92                  92
# 7        Nilam             78                  78
# 8         Deep             89                  89

# %%
df=df.drop(1)# remove the row

# %%
df
# Out:
#   Student Name  Student Attendance
# 0          Sam                  92
# 2         Amit                  67
# 3        Vijay                  45
# 4        Alina                  91
# 5         Ravi                  87
# 6         Zoya                  92
# 7        Nilam                  78
# 8         Deep                  89
