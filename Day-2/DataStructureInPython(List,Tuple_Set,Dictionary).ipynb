# %% [markdown]
# **List: is a collection of items stored in single variable.**

# %%
emps=['Sam','Ravi','Vijay','Amit']

# %%
print(emps)
# Out:
# ['Sam', 'Ravi', 'Vijay', 'Amit']

# %%
#indexing start from 0 and goes upto len-1
#len=Number of items in list
print("Number of items in list are: ",len(emps))
# Out:
# Number of items in list are:  4

# %%
for item in emps:
  print(item)
# Out:
# Sam
# Ravi
# Vijay
# Amit

# %%
#indexing start from 0 and goes upto len-1
for i in range(len(emps)):
  print(f'Index {i} -> Stored Value {emps[i]}')
# Out:
# Index 0 -> Stored Value Sam
# Index 1 -> Stored Value Ravi
# Index 2 -> Stored Value Vijay
# Index 3 -> Stored Value Amit

# %%
print('Employee from Index 2 is : \t',emps[2])
# Out:
# Employee from Index 2 is : 	 Vijay

# %%
print('Last Employee: ',emps[-1])
# Out:
# Last Employee:  Amit

# %%
numbers_list=[100,200,300,500,900]
print('Last Number from numbers_list: \t',numbers_list[-1])
# Out:
# Last Number from numbers_list: 	 900

# %%
print(numbers_list[2])
# Out:
# 300

# %%
# List Slicing
print(numbers_list[1:4])
# Out:
# [200, 300, 500]

# %%
print(numbers_list[:3])
# Out:
# [100, 200, 300]

# %%
print('Show me first Two Employee from emps')
print(emps[:2])
# Out:
# Show me first Two Employee from emps
# ['Sam', 'Ravi']

# %%
print('Show me last Two Employee from emps')
print(emps[2:])
# Out:
# Show me last Two Employee from emps
# ['Vijay', 'Amit']

# %%
print(emps)
# Out:
# ['Sam', 'Ravi', 'Vijay', 'Amit']

# %% [markdown]
# **Adding items in list**
# * append(item): add the item at the end of list
# * insert(position,item): add the item at given positon

# %%
emps
# Out:
# ['Sam', 'Ravi', 'Vijay', 'Amit']

# %%
emps.append('Zoya')

# %%
#emps
for item in emps:
   print(item)
# Out:
# Sam
# Ravi
# Vijay
# Amit
# Zoya

# %%
emps.insert(2,'Neha')

# %%
emps
# Out:
# ['Sam', 'Ravi', 'Neha', 'Vijay', 'Amit', 'Zoya']

# %% [markdown]
# Delete the Items:
# * clear(): Delete All Items
# * remove(item): remove the item by value
# * pop(): remove from the end means last item

# %%
print(len(emps))
# Out:
# 6

# %%
emps.clear()

# %%
print(len(emps))
# Out:
# 0

# %%
emps

# %%
emps=['Sam','Ravi','Vijay','Amit']
emps
# Out:
# ['Sam', 'Ravi', 'Vijay', 'Amit']

# %%
#removing Vijay from list
emps.remove('Vijay')

# %%
emps
# Out:
# ['Sam', 'Ravi', 'Amit']

# %%
#removing last item from list
emps.pop()
# Out:
# 'Amit'

# %%
emps
# Out:
# ['Sam', 'Ravi']

# %%
#insert, update,delete,search,slicing
#update
emps[0]='Sameer'

# %%
emps
# Out:
# ['Sameer', 'Ravi']

# %%
#Rearrange the item
#sort(): Asc
#reverse()
emps
# Out:
# ['Sameer', 'Ravi']

# %%
emps.sort()

# %%
emps
# Out:
# ['Ravi', 'Sameer']

# %%
car_list=['Proton','BMW','Tesla','Audi']
for car in car_list:
  print(car)
# Out:
# Proton
# BMW
# Tesla
# Audi

# %%
car_list.sort()
print('Car list in Ascending Order')
for car in car_list:
  print(car)
# Out:
# Car list in Ascending Order
# Audi
# BMW
# Proton
# Tesla

# %%
car_list.reverse()
print('Car list in Descending Order')
for car in car_list:
  print(car)
# Out:
# Car list in Descending Order
# Tesla
# Proton
# BMW
# Audi

# %%
#Use Case
shopping_cart=[]

# %%
choice='y'
while choice=='y':
  item=input('Enter the item to add in cart: ')
  shopping_cart.append(item)
  choice=input('Do you want to add more items? (y/n): ')

print('your shopping cart is: ',shopping_cart)
# Out:
# Enter the item to add in cart: Black Tea
# Do you want to add more items? (y/n): y
# Enter the item to add in cart: Milk
# Do you want to add more items? (y/n): y
# Enter the item to add in cart: Sugar
# Do you want to add more items? (y/n): n
# your shopping cart is:  ['Juice', 'Pizza', 'Side Dish', 'Black Tea', 'Milk', 'Sugar']

# %% [markdown]
# Tupe: is an ordered Immutable collection

# %%
week_days=('Sun','Mon','Tue','Wed','Thu','Fri','Sat')
print(week_days)
# Out:
# ('Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat')

# %%
for day in week_days:
  print(day)
# Out:
# Sun
# Mon
# Tue
# Wed
# Thu
# Fri
# Sat

# %%
numbers=(100,130,100,230,130,400,500,100)
print('Total Number of items are: ',len(numbers))
# Out:
# Total Number of items are:  8

# %%
#index of items and you can find out frequency of item
print('Index of 230 is: ',numbers.index(230))
#
# Out:
# Index of 230 is:  3

# %%
print('Frequency of 100 in numbers',numbers.count(100))
# Out:
# Frequency of 100 in numbers 3

# %%
# A list of employees using tuples (id,name,salary,designation)
employees=(
    (1,'Sam',5500,'Manager'),
    (2,'Ravi',4300,'Tester'),
    (3,'Alina',3500,'Developer'),
    (4,'Chang',3500,'HR'),
    (5,'Ali',3500,'HR'),
)

# %%
for emp in employees:
  print(f'ID:\t{emp[0]} \tName:\t{emp[1]} \t Salary: \t{emp[2]} \tDesignation:\t {emp[3]}')
# Out:
# ID:	1 	Name:	Sam 	 Salary: 	5500 	Designation:	 Manager
# ID:	2 	Name:	Ravi 	 Salary: 	4300 	Designation:	 Tester
# ID:	3 	Name:	Alina 	 Salary: 	3500 	Designation:	 Developer
# ID:	4 	Name:	Chang 	 Salary: 	3500 	Designation:	 HR
# ID:	5 	Name:	Ali 	 Salary: 	3500 	Designation:	 HR

# %% [markdown]
# Wrte a BankTransactions Record using Tuple.
# * Saved 3 transactions
# * Transaction content following:
#    TransactionId,Name,Amount,Date,Type
#    e.g. TXN-01 ,Sam, 250.50, '2025-11-13', 'NetBanking'
#
# * Show stored data

# %% [markdown]
# **Set: is an unordered collection of unique items,mutable.**

# %%
our_set={'fan','ac','washing machine','cooler','ac'}

# %%
print(our_set)
# Out:
# {'ac', 'washing machine', 'fan', 'cooler'}

# %%
#add(): to add the item in set
our_set.add('laptop')
print('Set after adding one more item')
for item in our_set:
    print(item)
# Out:
# Set after adding one more item
# cooler
# washing machine
# fan
# laptop
# ac

# %%
our_set.remove('cooler')
print('Set after removing one item')
for item in our_set:
  print(item)
# Out:
# Set after removing one item
# washing machine
# fan
# laptop
# ac

# %%
#union,intersection, difference
set_one={10,20,30,40,50}
set_two={5,10,15,20,25,30}
set_union=set_one.union(set_two)
print('Union of both sets')
print(set_union)
# Out:
# Union of both sets
# {5, 40, 10, 15, 50, 20, 25, 30}

# %%
set_intersection=set_one.intersection(set_two)
print('Intersection of both sets')
print(set_intersection)
# Out:
# Intersection of both sets
# {10, 20, 30}

# %%
set_difference=set_one.difference(set_two)
print('Difference of both sets')
print(set_difference)
# Out:
# Difference of both sets
# {40, 50}

# %%
set_difference=set_two.difference(set_one)
print('Difference of both sets')
print(set_difference)
# Out:
# Difference of both sets
# {25, 5, 15}

# %%
course_one={'Python','Power BI','Excel','SQL','Time Management','Soft Skill'}
course_two={'Python','Excel','SQL','Soft Skill','Tableau','TensorFlow','Azure','GitHub'}
print(course_one)
print(course_two)
# Out:
# {'Soft Skill', 'Time Management', 'SQL', 'Python', 'Excel', 'Power BI'}
# {'GitHub', 'TensorFlow', 'Python', 'Tableau', 'Azure', 'SQL', 'Soft Skill', 'Excel'}

# %%
common_courses=course_one.intersection(course_two)
print('Common Skills')
for course in common_courses:
  print(course)
# Out:
# Common Skills
# Soft Skill
# Excel
# SQL
# Python

# %%
course_union=course_one.union(course_two)
print('All Skills covered by both Training')
for course in course_union:
  print(course)
# Out:
# All Skills covered by both Training
# GitHub
# TensorFlow
# Python
# Tableau
# Azure
# Time Management
# SQL
# Soft Skill
# Excel
# Power BI

# %%
course_diff_one=course_one.difference(course_two)
print('Skills Covered by Course_one Only')
for course in course_diff_one:
  print(course)
# Out:
# Skills Covered by Course_one Only
# Time Management
# Power BI

# %%
course_diff_two=course_two.difference(course_one)
print('Skills Covered by course_two Only')
for course in course_diff_two:
  print(course)
# Out:
# Skills Covered by course_two Only
# Tableau
# GitHub
# Azure
# TensorFlow

# %% [markdown]
# Dictionary:is a mutable collection of key value pairs.
# keys are unique

# %%
players={'name':'Sachin','age':45,'country':'India'}
print(players)
# Out:
# {'name': 'Sachin', 'age': 45, 'country': 'India'}

# %%
print('All Keys')
for k in players:
  print(k)
# Out:
# All Keys
# name
# age
# country

# %%
print('All Keys')
for k in players.keys():
  print(k)
# Out:
# All Keys
# name
# age
# country

# %%
print('All Values')
for v in players.values():
  print(v)
# Out:
# All Values
# Sachin
# 45
# India

# %%
print('Key -> Value')
for k in players:
  print(f'{k} ->{players[k]}')
# Out:
# Key -> Value
# name ->Sachin
# age ->45
# country ->India

# %%
players['Type']='All-Rounder'
print(players)
# Out:
# {'name': 'Sachin', 'age': 45, 'country': 'India', 'Type': 'All-Rounder'}

# %%
# Empty dictionary to store one student record
student = {}

while True:
    print("\n--- Student Record System ---")
    print("1. Create Student Record")
    print("2. Read Student Record")
    print("3. Update Student Record")
    print("4. Delete Student Record")
    print("5. Exit")

    choice = input("Enter your choice (1-5): ")

    # CREATE
    if choice == "1":
        student["name"] = input("Enter student name: ")
        student["age"] = int(input("Enter age: "))
        student["grade"] = input("Enter grade: ")
        student["city"] = input("Enter city: ")
        print("\nRecord created successfully!")

    # READ
    elif choice == "2":
        if student:
            print("\n--- Student Record ---")
            for key, value in student.items():
                print(f"{key} : {value}")
        else:
            print("\nNo record found. Please create one first.")

    # UPDATE
    elif choice == "3":
        if student:
            field = input("Which field do you want to update? (name/age/grade/city): ")
            if field in student:
                new_value = input(f"Enter new value for {field}: ")
                student[field] = int(new_value) if field == "age" else new_value
                print("\nRecord updated successfully!")
            else:
                print("\nField does not exist!")
        else:
            print("\nNo record found. Please create one first.")

    # DELETE
    elif choice == "4":
        if student:
            confirm = input("Are you sure you want to delete the record? (yes/no): ")
            if confirm.lower() == "yes":
                student.clear()
                print("\nRecord deleted successfully!")
        else:
            print("\nNo record found to delete.")

    # EXIT
    elif choice == "5":
        print("\nExiting program. Goodbye!")
        break

    else:
        print("\nInvalid choice. Please select between 1–5.")
# Out:
# --- Student Record System ---
# 1. Create Student Record
# 2. Read Student Record
# 3. Update Student Record
# 4. Delete Student Record
# 5. Exit
